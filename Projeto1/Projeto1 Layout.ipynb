# %% [markdown]
# ___
# # Ciência dos Dados - PROJETO 1

# %% [markdown]
# ## COLOQUE AQUI SEU NOME
# ___

# %% [markdown]
# ## TÍTULO DO SEU PROJETO

# %% [markdown]
# ___
# ## Introdução
#
# Descreva aqui o que pretende analisar!
#
# Capriche no português!!
# Se quiser pode utilizar pesquisas semelhantes publicadas em sites confiáveis!!

# %% [markdown]
# ___
# ## Análise e Resultados

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
### no meu projeto 1 pretendo  pesquisar/estudar sobre a mudança dos habitos no acesso a internet, 
#levando em conta os aparelhos eletronicos utilizados e se eles reduziram o uso da tv ao longo dos anos###

# %%
print('Esperamos trabalhar no diretório')
print(os.getcwd())
# Out:
# Esperamos trabalhar no diretório
# C:\Users\Lucas\Downloads

# %%
#Se usar o arquivo descompactado
dados=pd.read_csv('DOM2015.csv',sep=',')
#print(dados)
#Se usar o arquivo compactado como está no dropbox púbico
#pd.read_csv('DOM2015csv.zip', compression='zip', header=0, sep=',', quotechar='"')

# %%
#pc dados relacao pc x
df=pd.DataFrame({"Tem microcomputador":dados.V0231,"Acessa internet do microcomputador":dados.V02323,"O acesso à Internet é feito por banda larga":dados.V02426,"Para acessar à Internet utiliza-se tablet":dados.V02325,"Tem televisão por assinatura":dados.V02272,"Para acessar à Internet utiliza-se telefone celular":dados.V02324})
#s=pd.DataFrame({"Acessa internet do microcomputador":dados.V02323})
#dados["Acessa internet do microcomputador"]=dados.V02323 #cópia da linha
#df.append(s)

#dados["Acessa internet do microcomputador"]=dados.V02323 #cópia da linha
#q=pd.DataFrame({"Acessa internet do celular":dados.V02324})
#print (df)
#df.apply(q,ignore_index=True)
#df2=pd.DataFrame
#df.iloc[2]
#dados.head(3)

df.dropna()
#dados.V0231=dados.V0231.astype('category')
#dados.V0231.cat.categories(['sim','Não'])
# Out:
#         Acessa internet do microcomputador  \
# 3                                      2.0
# 5                                      2.0
# 8                                      2.0
# 10                                     2.0
# 11                                     2.0
# 13                                     2.0
# 15                                     2.0
# 17                                     4.0
# 18                                     2.0
# 19                                     2.0
# 20                                     2.0
# 23                                     4.0
# 27                                     2.0
# 28                                     2.0
# 29                                     2.0
# 31                                     2.0
# 32                                     2.0
# 33                                     2.0
# 37                                     2.0
# 39                                     2.0
# 42                                     2.0
# ...

# %%
df.to_csv('variaveis1.csv')

# %%
#df1=pd.DataFrame({"O acesso à Internet é feito por banda larga":dados.V02426})
#q=pd.DataFrame({"Tem televisão por assinatura":dados.V02272})
#df1.append(q)

# %%
#df2=pd.DataFrame({"Para acessar à Internet utiliza-se telefone celular":dados.V02324})
#e=pd.DataFrame({"Para acessar à Internet utiliza-se tablet":dados.V02325})
#df2.append(e)

# %% [markdown]
# ### ___
# ## Conclusão

# %% [markdown]
# Descreva aqui suas conclusões!
